# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

sys.path.append("../")
import copy

from src.models import ModelandTokenizer
from causal_trace.plotting import plot_hidden_flow, plot_all_flow

# %%
model_name = "meta-llama/Meta-Llama-3-8B"
mt = ModelandTokenizer(model_path=model_name)
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
from src.functional import predict_next_token

year = 1971
country = "US"
# prompt = f"In {year}, the {country} president was named"
prompt = f"{country}, in {year}, had a president named"

predict_next_token(
    mt = mt, 
    prompt = prompt,
    k = 5
)
# Out:
# [[PredictedToken(token=' Richard', prob=0.7927711606025696),
#   PredictedToken(token=' Nixon', prob=0.14664791524410248),
#   PredictedToken(token=',', prob=0.0030435805674642324),
#   PredictedToken(token=' “', prob=0.00288160378113389),
#   PredictedToken(token=' "', prob=0.002297415165230632)]]

# %%
plot_hidden_flow(
    mt,
    prompt,
    subject=country,
    kind = None,
    model_name=mt.model_name.split("/")[-1],
)

# %%
plot_hidden_flow(
    mt,
    prompt,
    subject=str(year),
    kind = None,
    model_name=mt.model_name.split("/")[-1],
)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
