# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

sys.path.append("../")
import copy

from src.models import ModelandTokenizer
from causal_trace.plotting import plot_hidden_flow, plot_all_flow

# %%
model_name = "meta-llama/Llama-2-7b-hf"
mt = ModelandTokenizer(model_path=model_name)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
from src.functional import predict_next_token

year = 1971
country = "US"
prompt = f"In {year}, the {country} president was named"
# prompt = f"{country}, in {year}, had a president named"

predict_next_token(
    mt = mt, 
    prompt = prompt,
    k = 5
)
# Out:
# [[PredictedToken(token='Richard', prob=0.5432640910148621),
#   PredictedToken(token='N', prob=0.16568617522716522),
#   PredictedToken(token='Ger', prob=0.026628192514181137),
#   PredictedToken(token='“', prob=0.02207554690539837),
#   PredictedToken(token='as', prob=0.02207554690539837)]]

# %%
plot_hidden_flow(
    mt,
    prompt,
    subject=country,
    kind = None,
    model_name=mt.model_name.split("/")[-1],
)

# %%
plot_hidden_flow(
    mt,
    prompt,
    subject=str(year),
    kind = None,
    model_name=mt.model_name.split("/")[-1],
)
