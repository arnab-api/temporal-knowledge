# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

sys.path.append("../")
import copy

from src.models import ModelandTokenizer
from causal_trace.plotting import plot_hidden_flow, plot_all_flow

# %%
model_name = "meta-llama/Llama-2-7b-hf"
mt = ModelandTokenizer(model_path=model_name)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
from src.functional import predict_next_token

prompt = "In 1962, the US's President was named"
# prompt = "US, in 1962, had a President named"

predict_next_token(
    mt = mt, 
    prompt = prompt,
    k = 5
)
# Out:
# [[PredictedToken(token='John', token_id=2259, prob=0.5377707481384277),
#   PredictedToken(token='Kennedy', token_id=23166, prob=0.24814043939113617),
#   PredictedToken(token='Ly', token_id=8626, prob=0.024188319221138954),
#   PredictedToken(token='D', token_id=360, prob=0.01611289381980896),
#   PredictedToken(token='J', token_id=435, prob=0.01598750427365303)]]

# %%
plot_hidden_flow(
    mt,
    prompt,
    subject="US",
    kind = None,
    model_name=mt.model_name.split("/")[-1],
)

# %%
plot_hidden_flow(
    mt,
    prompt,
    subject="1962",
    kind = None,
    model_name=mt.model_name.split("/")[-1],
)
